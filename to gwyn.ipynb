# %% [markdown]
# ## *These are the things na need og explanation; im going to exclude data exploration since kabalo naka on what to do.*
#
# ## *MODELING (HYPERPARAMETER TUNING)*
#
# *each plot jud sa each model kailangan og explanation, just a brief explanation on the results. take a look at this:*
#
# ![image.png](attachment:image.png)
# - each trial is naa sa x-axis, our objective value is the f1-score meaning, f1-score atong gina try og maximize by finding the best possible combination of hyperparameters, and each trial naay gina test na combination of hyperparameters tas ang f1-score ana nga combination are *the blue dots*, for instance, the trial 6 kay iyang combination moy pinaka ubos og f1-score where ang objective value kay 0.3. NOTE: (same ra ang objective value og f1-score, different names lang)
# - and there's red line which is the atong pinaka the best f1-score and as you can see, mga trial 2 palang daan nakita nanato ang best value where wala najuy changes as the trial increases, in other words, nakita nanato ang best possible combination of hyperparameters as early as trial 2 cuz as we can see, nag converge najud sya sa trial 2 palang daan with little to no changes on wards.
#
# <hr>
#
#
# ![image-2.png](attachment:image-2.png)
# - a very simple plot that shows the significance of each parameter sa atong best value, and for this example, makita nanato na the threshold and the C has the most significance
#
#
# <hr>
#
# ![image-3.png](attachment:image-3.png)
#
# - this one is a bit complicated at first but kaya ra, ang plot kay ga start sya sa right side jud, not on the left, sa kani nga plot is sa logistic regression ni sya, as we can see sa right side, naay tol or tolerance, since kanang tol isa na sa hyperparameters na atong gina try og tune, after that ang threshold and the C, each blue line corresponds sa isa ka trial,  and ang ka baga sa color is nag depende sa iyang result or objective value in other words the bluer the higher the f1-score.
#
# ![image-4.png](attachment:image-4.png)
#
# if e check nimo ni danhi na part you may notice that a threshold of around 0.5 to 0.6 produces bluer lines or higher f1-score followed by 0.2 to 0.4 C.

# %% [markdown]
# ## *MODELING (MODEL EVALUATION)*
#
# some graphs need og explanation, such as the following:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# *after nanato makuha tanan results sa tanan model, it's time to choose unsa na model ang gamiton for deployment: now nag base ko ani nga table where naka summarize tanan results sa tanan model:*
#
# | Model         | Validation F1-Score     | Test Accuracy | Test Recall | Test Precision | Test F1-Score | Specificity |ROC-AUC |
# |--------------|-----------|------------|--------------|-----------|------------|------------|------------|
# | **Logistic Regression** |0.960|0.958|0.926|0.995|0.959|0.921|0.958|
# | **Random Forest**      |0.987|0.991|0.988|0.995|0.991|0.988|0.991|
# | **SVC**      |0.972|0.986|0.974|1.000|0.987|0.973|0.986|
# | **XGBOOST**      |0.987|0.990|0.985|0.995|0.990|0.985|0.990|
# | **LightGBM**      |0.987|0.997|0.997|0.997|0.997|0.997|0.997|
# | **MLP**      |0.997|0.990|1.000|0.979|0.989|0.980|0.990|
#
# - akong ge pili danhi is the lightGBM, why? well my short answer would probably due to its consistency sa metrics where there is little to no disparity sa validation f1-score sa testing f1-score
# - mas dako ang iyang f1-score and specificity in which mao jud atong main priority on model selection.
#
#
# *my answer above wont be acceptable sa atong paper, i want you to expound it as to why we chooose LGBM, you may also right your own thoughts, add add lang.*
